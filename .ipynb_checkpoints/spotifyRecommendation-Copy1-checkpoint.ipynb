# %% [markdown]
# ## Spotify Music Recommender
# After doing some research on clustering and recommendation algorithms used by Netflix, Spotify and other media content driven companies I was interested in making a recommendation algorithm myself.  I love music, mainly southern rock, rock, bluegrass, and jazz/blues and figured that using Spotify data to do something like this was a great idea.  I am also a avid Spotify user and have had a account for 6+ years!
#
# So the general overiew here is to import some data from spotify or kaggle...wherever I can find a good bit of data, do some pre-processing (i.e. normalize the data were need be, investigate correlation between features etc.), then cluster the data to find similar groups.  After this, the next part is to contruct the model and train it. I am going to use kNN and DBSCAN models to do the clustering. I'll mess around with parameters and compare their results using appropriate preformance parameters. I might do some research into other ML recommendation models and try to implement something of my own and see how it compares as well.  Finally, I plan to use this predictive algorithm to produce a "small batch playlist" of songs when given a user song input. The small batch idea came from a friend, Tabb Carneal, where he produces daily small batch playlist for users to listen too.  Check him out @dittylint on Instagram. Taking this further, would be to make unique playlist based on a user recommended song input and return a unique playlist of songs that the user has lightly listened to.  This would have to take into account what songs the user has listned to, liked songs etc. and formulating a playlist of songs that the user has not yet listened too much.

# %% [markdown]
# ### Data Pre-Processing

# %%
import pandas as pd
import numpy as np
import tensorflow as tf 

music = pd.read_csv("spotify.csv")
music.head()
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# 0   -12.628     0                           Keep A Song In Your Soul
# 1    -7.261     0                               I Put A Spell On You
# 2   -12.098     1                                       Golfing Papa
# 3    -7.311     1  True House Music - Xavier Santos & Carlos Gomi...
# 4    -6.036     0                                          Xuniverxe
#
#    popularity release_date  speechiness    tempo  valence  year
# 0          12         1920       0.0936  149.976   0.6340  1920
# 1           7   1920-01-05       0.0534   86.889   0.9500  1920
# 2           4         1920       0.1740   97.600   0.6890  1920
# 3          17   1920-01-01       0.0425  127.997   0.0422  1920
# 4           2   1920-10-01       0.0768  122.076   0.2990  1920

# %%
#checking for missing values 
music.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174389 entries, 0 to 174388
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   acousticness      174389 non-null  float64
#  1   artists           174389 non-null  object
#  2   danceability      174389 non-null  float64
#  3   duration_ms       174389 non-null  int64
#  4   energy            174389 non-null  float64
#  5   explicit          174389 non-null  int64
#  6   id                174389 non-null  object
#  7   instrumentalness  174389 non-null  float64
#  8   key               174389 non-null  int64
#  9   liveness          174389 non-null  float64
#  10  loudness          174389 non-null  float64
#  11  mode              174389 non-null  int64
#  12  name              174389 non-null  object
#  13  popularity        174389 non-null  int64
#  14  release_date      174389 non-null  object
#  15  speechiness       174389 non-null  float64
#  16  tempo             174389 non-null  float64
#  17  valence           174389 non-null  float64
#  18  year              174389 non-null  int64
# dtypes: float64(9), int64(6), object(4)
# memory usage: 25.3+ MB

# %%
# removing all columns of type object since they are associated with artist and albumn etc. 
features = music.select_dtypes(exclude='object')

#removed the popularity column because it is not apart of a songs "audio features"
#removed explicit since it is binary and does not contribute to the "audio features" of a song
features = features.drop(columns = ['popularity', 'explicit', 'year'])
features.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0      0.991000         0.598       168333   0.224          0.000522    5
# 1      0.643000         0.852       150200   0.517          0.026400    5
# 2      0.993000         0.647       163827   0.186          0.000018    0
# 3      0.000173         0.730       422087   0.798          0.801000    2
# 4      0.295000         0.704       165224   0.707          0.000246   10
#
#    liveness  loudness  mode  speechiness    tempo  valence
# 0    0.3790   -12.628     0       0.0936  149.976   0.6340
# 1    0.0809    -7.261     0       0.0534   86.889   0.9500
# 2    0.5190   -12.098     1       0.1740   97.600   0.6890
# 3    0.1280    -7.311     1       0.0425  127.997   0.0422
# 4    0.4020    -6.036     0       0.0768  122.076   0.2990

# %% [markdown]
# I am removing the mode feature due to the description below from the Spotify's Web API.  It seems that it does not carry a ton of information about the actual song, although it is considered a key feature.

# %%
features = features.drop(columns = ['mode'])
features.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0      0.991000         0.598       168333   0.224          0.000522    5
# 1      0.643000         0.852       150200   0.517          0.026400    5
# 2      0.993000         0.647       163827   0.186          0.000018    0
# 3      0.000173         0.730       422087   0.798          0.801000    2
# 4      0.295000         0.704       165224   0.707          0.000246   10
#
#    liveness  loudness  speechiness    tempo  valence
# 0    0.3790   -12.628       0.0936  149.976   0.6340
# 1    0.0809    -7.261       0.0534   86.889   0.9500
# 2    0.5190   -12.098       0.1740   97.600   0.6890
# 3    0.1280    -7.311       0.0425  127.997   0.0422
# 4    0.4020    -6.036       0.0768  122.076   0.2990

# %% [markdown]
# This information was taken from Spotify's Web API Reference page (https://developer.spotify.com/documentation/web-api/reference/#/operations/get-several-audio-features).
#
# Feature Descriptions:
#
#     Acusticness - A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
#
#     Danceability - Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
#     Energy - Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#
#     Instrumentalness - Predicts whether a track contains no vocals. "Ooh" and "aah" sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly "vocal". The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#
#     Key - The key the track is in. Integers map to pitches using standard Pitch Class notation. E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.
#
#     Liveness - Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#
#     Loudness - The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typically range between -60 and 0 db.
#
#     Mode - Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0.
#
#     Speechiness - Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#
#     Tempo -  The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
#     Valence - A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).

# %% [markdown]
#  ### Principal Component Analysis
#  Going to try to implement this on my own to do some of the math and then with sklearn as well. Will plan to train and test on these models as well to compare preformance.

# %% [markdown]
# #### Correlation Between Features
# We see that there is a high correlation between energy, loudness, and acousticness.  Due to the curse of dimensionality and an effort to save computational power, I am going to drop energy as a feature. If I droped loudness as well, then I feel like there might be a loss of information in the data set.  Dropping just energy leaves the next highlest correlation of .55 between acousticness and loudness which is not too high, therefore I am choosing to leave loudness in the data set.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,10))
sns.heatmap(features.corr(),annot=True, cmap='coolwarm',fmt='.2f')
plt.show()

#dropping energy 
features.drop(columns = {'energy'}, inplace = True)

plt.figure(figsize=(12,10))
sns.heatmap(features.corr(),annot=True, cmap='coolwarm',fmt='.2f')
plt.show()

# %% [markdown]
# #### Normilization

# %%
col_names = list(features)
x = features.loc[:,:].values

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

x = MinMaxScaler().fit_transform(x)
#x = StandardScaler().fit_transform(x)
frame = pd.DataFrame(x, columns = col_names)
frame.head()
# Out:
#    acousticness  danceability  duration_ms  instrumentalness       key  \
# 0      0.994980      0.605263     0.030637          0.000522  0.454545
# 1      0.645582      0.862348     0.027237          0.026400  0.454545
# 2      0.996988      0.654858     0.029792          0.000018  0.000000
# 3      0.000174      0.738866     0.078215          0.801000  0.181818
# 4      0.296185      0.712551     0.030054          0.000246  0.909091
#
#    liveness  loudness  speechiness     tempo  valence
# 0    0.3790  0.741868     0.096395  0.615900   0.6340
# 1    0.0809  0.825918     0.054995  0.356823   0.9500
# 2    0.5190  0.750168     0.179197  0.400810   0.6890
# 3    0.1280  0.825135     0.043769  0.525640   0.0422
# 4    0.4020  0.845102     0.079094  0.501324   0.2990

# %% [markdown]
# #### Finding Covariance Matrix

# %%
def cov(x):
    mean_x = x.mean(axis = 0)
    covarMatrix = np.ones((len(x[1]),len(x[1])))
    for i in range(len(mean_x)): 
        for j in range(len(mean_x)): 
            num = np.dot((x[:,i] - mean_x[i]), (x[:,j] - mean_x[j]))
            den = len(x) - 1
            covar = num/(len(x) - 1) 
            covarMatrix[i,j] = covar
    return covarMatrix

#finding covariance matrix
covar = cov(x)

#converting to dataframe to clean up the visualization
covar_df = pd.DataFrame(covar)
covar_df
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.145513 -0.017889 -0.000946  0.028328 -0.003420 -0.002042 -0.018586
# 1 -0.017889  0.031742 -0.000499 -0.012851  0.001497 -0.003538  0.003963
# 2 -0.000946 -0.000499  0.000774  0.000965  0.000018  0.000145  0.000049
# 3  0.028328 -0.012851  0.000965  0.111940 -0.000494 -0.002895 -0.009470
# 4 -0.003420  0.001497  0.000018 -0.000494  0.102301 -0.000194  0.000719
# 5 -0.002042 -0.003538  0.000145 -0.002895 -0.000194  0.032578  0.001009
# 6 -0.018586  0.003963  0.000049 -0.009470  0.000719  0.001009  0.007945
# 7 -0.001607  0.008025 -0.000511 -0.008413  0.000579  0.004134 -0.003572
# 8 -0.010609  0.000121 -0.000028 -0.002854  0.000199  0.000193  0.002413
# 9 -0.016845  0.025290 -0.001348 -0.019395  0.002165 -0.000276  0.007131
#
#           7         8         9
# 0 -0.001607 -0.010609 -0.016845
# 1  0.008025  0.000121  0.025290
# 2 -0.000511 -0.000028 -0.001348
# 3 -0.008413 -0.002854 -0.019395
# 4  0.000579  0.000199  0.002165
# 5  0.004134  0.000193 -0.000276
# 6 -0.003572  0.002413  0.007131
# 7  0.035233 -0.000782  0.002512
# 8 -0.000782  0.015436  0.005360
# 9  0.002512  0.005360  0.069948

# %% [markdown]
# #### Computing Eigenvalues and Eigenvectors

# %%
val, vec = np.linalg.eig(covar)

#ordering them
idx = val.argsort()[::-1]   
val = val[idx]
vec = vec[:,idx]

#plotting
s = np.sum(val)
percent_var = val/s

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
comp = list(range(10))
ax.bar(comp, percent_var)
plt.xlabel('Principal Components')
plt.ylabel('Percent Variance')
plt.show()

# %%
#cumulative sum of variance for principal component
#computed two different ways

tot_var = []
dummy = 0 
for var in percent_var:
    tot_var.append(var + dummy)
    dummy = var + dummy 
tot_var = [percent * 100 for percent in tot_var]
print(np.round_(tot_var, decimals = 1))

var = np.cumsum(np.round(percent_var, decimals=3)*100)
print(var)
# Out:
# [ 32.1  50.6  68.5  81.   87.9  93.8  96.8  99.1  99.9 100. ]
# [ 32.1  50.6  68.5  81.   87.9  93.7  96.8  99.1  99.9 100. ]

# %% [markdown]
# #### Final Data Transformed into New Feature Space

# %%
f = vec.T.dot(x.T)
features_trans = np.matmul(vec.transpose(), x.transpose())
features_trans_df = pd.DataFrame(features_trans)
features_trans_df
f_df = pd.DataFrame(f)
f_df.head()
#features_trans_df.head()
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.320987 -0.062672  0.329185  0.078260 -0.189314  0.807869  0.349275
# 1 -0.294908 -0.325503  0.149939 -0.362259 -0.818327 -0.502298 -0.299596
# 2 -0.884903 -0.768563 -0.802895  0.476171 -0.531117 -0.255155 -0.869031
# 3 -0.844717 -1.180124 -0.916067 -0.648069 -0.496627 -0.983046 -0.797051
# 4  0.139381 -0.004063  0.291353  0.171611  0.197265  0.109891  0.080503
#
#      7         8         9       ...    174379    174380    174381    174382  \
# 0  0.514916  0.831121  0.100428  ...  0.333833 -0.361513  0.333833 -0.297397
# 1 -0.704415 -0.798464 -0.903460  ... -0.249065 -0.057507 -0.249065 -0.302668
# 2 -0.769980 -0.253350  0.377122  ... -0.628969 -0.184514 -0.628969 -0.347747
# 3 -0.638715 -1.178958 -0.655926  ... -0.434806 -0.571909 -0.434806 -0.619391
# 4  0.038071  0.115142  0.126129  ...  0.038009  0.113482  0.038009  0.235372
#
#      174383    174384    174385    174386    174387    174388
# 0  0.333833 -0.380330  0.333833  0.611937  0.400461  0.120702
# 1 -0.249065 -0.505935 -0.249065 -0.453978  0.115778 -0.767746
# 2 -0.628969 -0.243155 -0.628969 -0.115179 -0.619901  0.108743
# 3 -0.434806 -0.438462 -0.434806 -1.309807 -0.574498 -1.237272
# 4  0.038009  0.091918  0.038009  0.079344 -0.022899  0.127697
#
# [5 rows x 174389 columns]

# %% [markdown]
# #### Sklearn Principal Component Analysis

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=(len(x[0])-2))
pca.fit(x)
x_new = pca.fit_transform(x)

variance = pca.explained_variance_ratio_
eigvals  = pca.singular_values_
eigvecs  = pca.components_
var_cumul  = np.cumsum(np.round(variance, decimals=3)*100)
print(var_cumul) 

x_new = pd.DataFrame(x_new)
x_new.head()
# Out:
# [32.1 50.6 68.5 81.  87.9 93.7 96.8 99.1]
#           0         1         2         3         4         5         6  \
# 0  0.242791 -0.125465 -0.449566  0.083480  0.025251  0.169168  0.014082
# 1 -0.140868 -0.094869 -0.333226  0.418888 -0.118192 -0.103220 -0.174225
# 2  0.250989 -0.570312 -0.367558  0.154830  0.177223  0.233730 -0.140693
# 3  0.000064 -0.058114  0.911508 -0.113167  0.057482 -0.210998 -0.212228
# 4 -0.267509  0.397954 -0.095780 -0.264610  0.083135  0.076413 -0.206750
#
#           7
# 0 -0.180042
# 1  0.036627
# 2 -0.027401
# 3 -0.219680
# 4 -0.173066

# %% [markdown]
# #### Comparing PCAs

# %%
# comparing eigenvectors
# shows that they produce the same eigenvectors just with some different minus signs
# minus signs show that they are being stretched in opposite directions
#display(pd.DataFrame(eigvecs).compare(pd.DataFrame(vec.T), align_axis=0))


# comparing eigenvalues
#val1 = pd.DataFrame(eigvals)
#val2 = pd.DataFrame(val)
#display(pd.concat([val1, val2], axis = 1))
#display(pd.DataFrame(eigvals).compare(pd.DataFrame(val), align_axis=0))

# %% [markdown]
# #### Visualizing Data

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 3)
x_vis = pca.fit_transform(x)
x_vis = pd.DataFrame(x_vis)

#randomly getting a subset of the transformed data
x_vis_sub = x_vis.sample(n=10000)
x_vis_sub = x_vis_sub.to_numpy()

plt.figure(figsize=(8,6))
plt.scatter(x_vis_sub[:,0], x_vis_sub[:,1], cmap='rainbow')
plt.xlabel('1st Principal component')
plt.ylabel('2nd Principal Component')
plt.title("PCA Visualization - 2 Components")
plt.show()


fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 
# Creating plot - basically looks like a 3d cube of points with points unevenly spaced within the cube 
ax.scatter3D(x_vis_sub[:,0], x_vis_sub[:,1], x_vis_sub[:,2])
plt.title("PCA Visualization - 3 Components")
plt.xlabel('1st Principal component')
plt.ylabel('2nd Principal Component')
ax.set_zlabel('3rd Principal component')
ax.view_init(-140, 60)
plt.show()

# %% [markdown]
# ### K-Means
# Looking at the Elbow Method we can see that the optimal k is either 8-10 or 14-15 depending on how you look at the "elbow" of the plot.  Using the Silhouette Score to help make this decision, one can see that k=8 would produce the best results.
#
# I struggled with the silhouette scores and trying to decipher if I actually was calculating the score correctly. I don't fully understand why the score decreases as k increases.  From the number of samples in the data set and know about various music categories, I would assume that at least 20 clusters would produce optimal results.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score as ss

wcss = []
labels = []
sil_scores = []
max_K = 50
K = range(2,max_K)
for k in K: 
    kmeans = KMeans(n_clusters=k)
    kmeans = kmeans.fit(x_new)
    sil_scores.append(ss(x_new, kmeans.labels_, sample_size = 10000, metric = "euclidean"))
    wcss.append(kmeans.inertia_)
    labels.append(kmeans.labels_)
    if k % 10 == 0: 
        print("----------------")
        print("KMeans: K = ", k)
# Out:
# ----------------
# KMeans: K =  10
# ----------------
# KMeans: K =  20
# ----------------
# KMeans: K =  30
# ----------------
# KMeans: K =  40

# %%
#plotting
plt.plot(K, wcss, 'x-')
plt.xlabel('Number of centroids')
plt.ylabel('WCSS')
plt.title('Elbow Method For Optimal k')
plt.show()

plt.plot(K[0:20], wcss[0:20], 'x-')
plt.xlabel('Number of centroids')
plt.ylabel('WCSS')
plt.title('Elbow Method For Optimal k - K from 2 - 40')
plt.show()

plt.plot(range(2, max_K), sil_scores, 'x-')
plt.xlabel('Number of centroids')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Method For Optimal k')
plt.show()

best_k = K[6]
best_lab = labels[6]

print("SILHOUETTE SCORES:")
print("--------------")
print("MAX SILHOUEET SCORE: ", np.max(sil_scores))
print("CORRESPONDING K: ", K[sil_scores.index(np.max(sil_scores))])
print("--------------")

for i in range(0,30):
    print("K = ", K[i])
    print("Silhouette Score = ", sil_scores[i])
    print("--------------")
# Out:
# 0
# SILHOUETTE SCORES:
# --------------
# MAX SILHOUEET SCORE:  0.2395699176454427
# CORRESPONDING K:  3
# --------------
# K =  2
# Silhouette Score =  0.2377255123411711
# --------------
# K =  3
# Silhouette Score =  0.2395699176454427
# --------------
# K =  4
# Silhouette Score =  0.22506968930467638
# --------------
# K =  5
# Silhouette Score =  0.236425455466024
# --------------
# K =  6
# Silhouette Score =  0.22606422534922344
# --------------
# K =  7
# Silhouette Score =  0.21655289114784426
# --------------
# K =  8
# Silhouette Score =  0.2377162485392693
# --------------
# K =  9
# Silhouette Score =  0.22462292381288643
# --------------
# K =  10
# Silhouette Score =  0.2163278481106112
# --------------
# K =  11
# Silhouette Score =  0.20673620595313114
# --------------
# K =  12
# Silhouette Score =  0.19938486616750953
# --------------
# K =  13
# Silhouette Score =  0.20459514433304812
# --------------
# K =  14
# Silhouette Score =  0.20429482161753673
# --------------
# K =  15
# Silhouette Score =  0.20436285795436276
# --------------
# K =  16
# Silhouette Score =  0.19809039473139647
# --------------
# K =  17
# Silhouette Score =  0.19703379730284581
# --------------
# K =  18
# Silhouette Score =  0.2001836163637919
# --------------
# K =  19
# Silhouette Score =  0.19937283676916545
# --------------
# K =  20
# Silhouette Score =  0.19140589000317823
# --------------
# K =  21
# Silhouette Score =  0.199017651093852
# --------------
# K =  22
# Silhouette Score =  0.19128867753907858
# --------------
# K =  23
# Silhouette Score =  0.18877325231642586
# --------------
# K =  24
# Silhouette Score =  0.17721503527534574
# --------------
# K =  25
# Silhouette Score =  0.18928200013197233
# --------------
# K =  26
# Silhouette Score =  0.18821311035341376
# --------------
# K =  27
# Silhouette Score =  0.17854237870008055
# --------------
# K =  28
# Silhouette Score =  0.17254669810811707
# --------------
# K =  29
# Silhouette Score =  0.17306597105166638
# --------------
# K =  30
# Silhouette Score =  0.16888120674023346
# --------------
# K =  31
# Silhouette Score =  0.16882572843161547
# --------------

# %% [markdown]
# #### Plotting Optimal Results with Kmeans

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_vis.iloc[:,0], x_vis.iloc[:,1], c=labels[8], cmap='rainbow')
plt.title("Classification of Data with K = 8 w/ First two PCs")  
plt.xlabel('1st Principal component')
plt.ylabel('2nd Principal Component')
plt.show()

fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 
ax.scatter3D(x_vis.iloc[:,0], x_vis.iloc[:,1], x_vis.iloc[:,2], c=labels[8], cmap='rainbow')
plt.title("Classification of Data with K = 8 w/ First three PCs")  
plt.xlabel('1st Principal component')
plt.ylabel('2nd Principal Component')
ax.set_zlabel('3rd Principal component')
#ax.view_init(-140, 60)
plt.show()

# %% [markdown]
# #### Putting Meaning to the Classes

# %%
# adding labels to original data set 
music['label'] = best_lab

#making a smaller dataset to determine the characteristics of each class 
music_sub = music[['artists','name', 'popularity', 'year', 'label']]
music_sub = music_sub.sort_values(by = ['label','popularity'], ascending = (False, False))
music_sub.groupby('label').head(20)

#try and use spotipy to get genere of listed songs to classify each group broadly as either pop, rock, RNB, etc.
# Out:
#                                                   artists  \
# 19866                                   ['Ariana Grande']
# 19886                        ['Bad Bunny', 'Jhay Cortez']
# 19976                                         ['KAROL G']
# 19868                                   ['Ariana Grande']
# 19870                                              ['CJ']
# 19872                                   ['The Kid LAROI']
# 19880                  ['Cardi B', 'Megan Thee Stallion']
# 19884                                       ['Lil Nas X']
# 20068                                   ['Justin Bieber']
# 76406                                            ['Boza']
# 19670                                    ['Harry Styles']
# 19924                   ['Shawn Mendes', 'Justin Bieber']
# 19974                                             ['BTS']
# 20018                        ['Bad Bunny', 'Jhay Cortez']
# 19902   ['Internet Money', 'Gunna', 'Don Toliver', 'NAV']
# 39230                                            ['HVME']
# 39368   ['Sech', 'Daddy Yankee', 'J Balvin', 'ROSALÍA'...
# 76546                      ['Sebastian Yatra', 'Guaynaa']
# 19666                                     ['Post Malone']
# 19882                               ['Drake', 'Lil Durk']
# 76408                           ['Sista Prod', 'Subvrbs']
# 19428                                    ['XXXTENTACION']
# 38896                                  ['SadBoyProlific']
# 110034                           ['Sub Urban', 'REI AMI']
# 19144                          ['A Boogie Wit da Hoodie']
# 76204                                    ['Taylor Swift']
# 93628                        ['Cordae', 'Anderson .Paak']
# 19048   ['Lin-Manuel Miranda', 'Leslie Odom Jr.', 'Ant...
# 38564                                              ['NF']
# 76312                           ['J.I the Prince of N.Y']
# 110108                                         ['2KBABY']
# 18756   ['Nicki Minaj', 'Drake', 'Lil Wayne', 'Chris B...
# 18826                                         ['J. Cole']
# 57268                                     ['Wale', 'SZA']
# 126099                                        ['J. Cole']
# 126361                                        ['Mulatto']
# 142905                                      ['Lil Kapow']
# 93240                                           ['Smino']
# 109896                                       ['Rod Wave']
# 126249                                   ['Hobo Johnson']
# 19878                                       ['Pop Smoke']
# 19712                                     ['Tones And I']
# 93760                               ['Camilo', 'El Alfa']
# 19736                                        ['Maroon 5']
# 93850        ['Maluma', 'Lenny Tavárez', 'Justin Quiles']
# 8662                                       ['Brenda Lee']
# 8462                                    ['Andy Williams']
# 19264                                    ['XXXTENTACION']
# 19490                                    ['XXXTENTACION']
# 18064                                   ['Justin Bieber']
# 18878                                ['Melanie Martinez']
# 19502                                    ['XXXTENTACION']
# 39276                                        ['347aidan']
# 19556                                            ['Lauv']
# 19796                                     ['Sam Fischer']
# 39270                                       ['Sara Kays']
# 110092                              ['Piso 21', 'Maluma']
# 17470                                      ['Jason Mraz']
# 39308                                  ['StaySolidRocky']
# 93738                           ['Anuel AA', 'Bad Bunny']
# 20062                                  ['Olivia Rodrigo']
# 19900                                      ['Tate McRae']
# 19908                   ['Justin Bieber', 'benny blanco']
# 19896                                      ['Conan Gray']
# 19988                                      ['Ed Sheeran']
# 19898                                    ['Taylor Swift']
# 19954                            ['Powfu', 'beabadoobee']
# 19062                                    ['James Arthur']
# 19472                         ['Billie Eilish', 'Khalid']
# 19694                                    ['Harry Styles']
# 19962                           ['Pop Smoke', 'Lil Tjay']
# 19068                                    ['James Arthur']
# 18470                                     ['John Legend']
# 19714                                   ['Billie Eilish']
# 39350                                       ['Bad Bunny']
# 19498                                    ['XXXTENTACION']
# 19744                                        ['Labrinth']
# 20008                                      ['Noah Cyrus']
# 16265                                        ['Coldplay']
# 39228                                 ['Drake', 'Giveon']
# 19862                           ['24kGoldn', 'iann dior']
# 19876                                   ['Billie Eilish']
# 19928                            ['Bad Bunny', 'ROSALÍA']
# 39252                                          ['Tiësto']
# 19874                 ['Pop Smoke', 'Lil Baby', 'DaBaby']
# 19892                           ['DaBaby', 'Roddy Ricch']
# 19984                                             ['BTS']
# 39236                              ['Joel Corry', 'MNEK']
# 39424   ['Manuel Turizo', 'Rauw Alejandro', 'Myke Towe...
# 76488                             ['Myke Towers', 'Juhn']
# 14662                                    ['Mariah Carey']
# 19894                              ['Dua Lipa', 'DaBaby']
# 19934              ['Justin Bieber', 'Chance the Rapper']
# 19996                                       ['Bad Bunny']
# 20048                        ['MEDUZA', 'Dermot Kennedy']
# 76578                                         ['Farruko']
# 93700                                          ['Camilo']
# 18462                               ['The Neighbourhood']
# 19662                                     ['Roddy Ricch']
# 19780                                    ['Topic', 'A7S']
# 19470                                             ['Sia']
# 19864                                             ['SZA']
# 19672                                   ['Lewis Capaldi']
# 19668                                          ['Clairo']
# 19682                       ['JP Saxe', 'Julia Michaels']
# 19730                                   ['Ariana Grande']
# 39280                                         ['Fousheé']
# 39416                                     ['Pink Sweat$']
# 76550                                        ['Jerry Di']
# 7262                                      ['Bobby Helms']
# 18262                                   ['Michael Bublé']
# 19380                                      ['Ed Sheeran']
# 19776                                   ['Lewis Capaldi']
# 19922                                    ['Taylor Swift']
# 7662                                      ['Dean Martin']
# 12462                                      ['The Police']
# 14663             ['Frank Sinatra', 'B. Swanson Quartet']
# 19466                                            ['Joji']
# 19486                         ['Post Malone', 'Swae Lee']
# 19518                                    ['Kina', 'Snøw']
# 19704                                   ['Billie Eilish']
# 19302   ['Erik Eriksson', 'White Noise Baby Sleep', 'W...
# 19432                                    ['Jack Stauber']
# 19326                                        ['Granular']
# 38892                           ['High Altitude Samples']
# 18488                                           ['Lorde']
# 37838   ['Ludovico Einaudi', 'Daniel Hope', 'I Virtuos...
# 57914                                    ['Molchat Doma']
# 76472                                      ['Thundercat']
# 18506                                    ['salvia palth']
# 19628                                            ['Joji']
# 76248                                        ['Labrinth']
# 38368                                   ['Petit Biscuit']
# 38734                                           ['sagun']
# 57692                                       ['Novo Amor']
# 17360                                    ['Radical Face']
# 18942   ['Ocean Waves For Sleep', 'Ocean Sounds Collec...
# 36071                                ['Ludovico Einaudi']
# 39018                                     ['Men I Trust']
# 57648                                            ['Joji']
# 19746                                         ['Dayglow']
# 19822                                     ['Frank Ocean']
# 17334              ['Timbaland', 'Keri Hilson', 'D.O.E.']
# 17938                                        ['Gorillaz']
# 18316                                     ['Tame Impala']
# 37518                                          ['Avicii']
# 38722                        ['itssvd', 'Shiloh Dynasty']
# 57662                                            ['RŮDE']
# 11279                                     ['David Bowie']
# 14864                           ['The Smashing Pumpkins']
# 18120                                      ['AWOLNATION']
# 57526                            ['Vicetone', 'Tony Igy']
# 158141                                         ['FISHER']
# 18314                                     ['Mac DeMarco']
# 18714                                     ['Mac DeMarco']
# 37932                 ['Daft Punk', 'Julian Casablancas']
# 16506                                     ['The Strokes']
# 14866                           ['The Smashing Pumpkins']
# 15996                                        ['Alice DJ']
# 17914                                        ['Kid Cudi']
#
#                                                      name  popularity  year  \
# 19866                                           positions          96  2020
# 19886                                              DÁKITI          95  2020
# 19976                                             BICHOTA          95  2020
# 19868                                               34+35          94  2020
# 19870                                             Whoopty          94  2020
# 19872                                         WITHOUT YOU          94  2020
# 19880                     WAP (feat. Megan Thee Stallion)          92  2020
# 19884                                             HOLIDAY          92  2020
# 20068                                              Anyone          92  2021
# 76406                                        Hecha Pa' Mi          92  2020
# 19670                                    Watermelon Sugar          91  2019
# 19924              Monster (Shawn Mendes & Justin Bieber)          91  2020
# 19974                                        Life Goes On          91  2020
# 20018                                              DÁKITI          91  2020
# 19902                                            Lemonade          90  2020
# 39230                                          Goosebumps          90  2020
# 39368                                    Relación - Remix          90  2020
# 76546                                         Chica Ideal          90  2020
# 19666                                             Circles          89  2019
# 19882                Laugh Now Cry Later (feat. Lil Durk)          89  2020
# 76408         Eyes Blue Like The Atlantic (feat. Subvrbs)          79  2020
# 19428                                            Carry On          77  2017
# 38896                                       Dead and Cold          76  2018
# 110034                              Freak (feat. REI AMI)          76  2020
# 19144                                              Jungle          73  2016
# 76204                           I Forgot That You Existed          73  2019
# 93628                          RNP (feat. Anderson .Paak)          71  2019
# 19048                                     Aaron Burr, Sir          70  2015
# 38564                              How Could You Leave Us          70  2016
# 76312                                         Blame on Me          70  2019
# 110108                                        Old Streets          70  2020
# 18756                                                Only          68  2014
# 18826                                  A Tale of 2 Citiez          68  2014
# 57268                        The Need to Know (feat. SZA)          66  2015
# 126099                                                ATM          66  2018
# 126361                                 B*tch From Da Souf          66  2019
# 142905                                           BLACKOUT          66  2019
# 93240                                         Amphetamine          65  2017
# 109896                                        Green Light          64  2019
# 126249                                        Peach Scone          64  2018
# 19878                             What You Know Bout Love          93  2020
# 19712                                        Dance Monkey          89  2019
# 93760                                                BEBÉ          89  2020
# 19736                                            Memories          88  2019
# 93850                         Parce (feat. Justin Quiles)          88  2020
# 8662                    Rockin' Around The Christmas Tree          87  1964
# 8462             It's the Most Wonderful Time of the Year          85  1963
# 19264                  Everybody Dies In Their Nightmares          85  2017
# 19490                                           Moonlight          85  2018
# 18064                                           Mistletoe          84  2011
# 18878                                           Play Date          84  2015
# 19502                                             changes          84  2018
# 39276                                  Dancing in My Room          84  2020
# 19556                                    I Like Me Better          83  2018
# 19796                                           This City          83  2019
# 39270                                Remember That Night?          83  2020
# 110092                                      Más De La Una          83  2020
# 17470                                           I'm Yours          82  2008
# 39308                                          Party Girl          82  2020
# 93738                                 Hasta Que Dios Diga          82  2020
# 20062                                     drivers license         100  2021
# 19900                                  you broke me first          93  2020
# 19908                          Lonely (with benny blanco)          92  2020
# 19896                                             Heather          91  2020
# 19988                                           Afterglow          90  2020
# 19898                                              willow          89  2020
# 19954                    death bed (coffee for your head)          89  2020
# 19062                                         Train Wreck          88  2016
# 19472                                lovely (with Khalid)          88  2018
# 19694                                             Falling          87  2019
# 19962                        Mood Swings (feat. Lil Tjay)          87  2020
# 19068                                Say You Won't Let Go          86  2016
# 18470                                           All of Me          85  2013
# 19714                               when the party's over          85  2019
# 39350                                HACIENDO QUE ME AMAS          85  2020
# 19498                                                Hope          84  2018
# 19744                            Still Don't Know My Name          84  2019
# 20008                                                July          84  2020
# 16265                                       The Scientist          83  2002
# 39228                    Chicago Freestyle (feat. Giveon)          83  2020
# 19862                              Mood (feat. iann dior)          96  2020
# 19876                                      Therefore I Am          94  2020
# 19928                                  LA NOCHE DE ANOCHE          94  2020
# 39252                                        The Business          92  2020
# 19874             For The Night (feat. Lil Baby & DaBaby)          91  2020
# 19892                        ROCKSTAR (feat. Roddy Ricch)          91  2020
# 19984                                            Dynamite          91  2020
# 39236                           Head & Heart (feat. MNEK)          91  2020
# 39424                                             La Nota          91  2020
# 76488                                             Bandido          91  2020
# 14662                     All I Want for Christmas Is You          90  1994
# 19894                           Levitating (feat. DaBaby)          90  2020
# 19934                      Holy (feat. Chance The Rapper)          90  2020
# 19996                                          TE MUDASTE          90  2020
# 20048                     Paradise (feat. Dermot Kennedy)          90  2020
# 76578                                           La Tóxica          90  2020
# 93700                                        Vida de Rico          90  2020
# 18462                                     Sweater Weather          89  2013
# 19662                                             The Box          89  2019
# 19780                                         Breaking Me          89  2019
# 19470                                             Snowman          91  2018
# 19864                                           Good Days          91  2020
# 19672                                   Someone You Loved          90  2019
# 19668                                               Sofia          87  2019
# 19682      If the World Was Ending - feat. Julia Michaels          86  2019
# 19730                                             7 rings          86  2019
# 39280                                            Deep End          86  2020
# 39416                                         At My Worst          86  2020
# 76550                                           Mi Cuarto          86  2020
# 7262                                     Jingle Bell Rock          85  1957
# 18262         It's Beginning to Look a Lot like Christmas          85  2012
# 19380                                        Shape of You          85  2017
# 19776                                       Before You Go          85  2019
# 19922                                  champagne problems          85  2020
# 7662               Let It Snow! Let It Snow! Let It Snow!          84  1959
# 12462                               Every Breath You Take          84  1983
# 14663   Let It Snow! Let It Snow! Let It Snow! (with T...          84  1994
# 19466                            SLOW DANCING IN THE DARK          84  2018
# 19486       Sunflower - Spider-Man: Into the Spider-Verse          84  2018
# 19518                       Get You The Moon (feat. Snøw)          84  2018
# 19704                                 everything i wanted          86  2019
# 19302           Clean White Noise - Loopable with no fade          84  2017
# 19432                                           Buttercup          78  2017
# 19326                                White Noise - 145 hz          77  2017
# 38892                                    Soft Brown Noise          77  2018
# 18488                                                Ribs          76  2013
# 37838                                          Experience          76  2013
# 57914                                 Судно (Борис Рижий)          76  2018
# 76472                                         Funny Thing          76  2020
# 18506                                  i was all over her          75  2013
# 19628                         worldstar money (interlude)          75  2018
# 76248                                             Forever          75  2019
# 38368                                        Sunset Lover          74  2015
# 38734                                  I'll Keep You Safe          74  2017
# 57692                                              Anchor          73  2017
# 17360                                   Welcome Home, Son          72  2007
# 18942                                 Rolling Ocean Waves          72  2015
# 36071                                      Nuvole Bianche          72  2004
# 39018                                         Show Me How          72  2018
# 57648                         worldstar money (interlude)          72  2017
# 19746                             Can I Call You Tonight?          81  2019
# 19822                                          In My Room          78  2019
# 17334                                       The Way I Are          76  2007
# 17938                                  On Melancholy Hill          76  2010
# 18316                     Feels Like We Only Go Backwards          76  2012
# 37518                                 Levels - Radio Edit          76  2011
# 38722                                     Losing Interest          76  2017
# 57662                                       Eternal Youth          76  2017
# 11279                              Heroes - 2017 Remaster          75  1977
# 14864                              1979 - Remastered 2012          75  1995
# 18120                                                Sail          75  2011
# 57526                                          Astronomia          75  2016
# 158141                                          Losing It          75  2018
# 18314                                    My Kind of Woman          74  2012
# 18714                               Chamber Of Reflection          74  2014
# 37932            Instant Crush (feat. Julian Casablancas)          74  2013
# 16506                                            Reptilia          73  2003
# 14866       Bullet With Butterfly Wings - Remastered 2012          72  1995
# 15996                                    Better Off Alone          72  2000
# 17914                                           Mr. Rager          72  2010
#
#         label
# 19866       7
# 19886       7
# 19976       7
# 19868       7
# 19870       7
# 19872       7
# 19880       7
# 19884       7
# 20068       7
# 76406       7
# 19670       7
# 19924       7
# 19974       7
# 20018       7
# 19902       7
# 39230       7
# 39368       7
# 76546       7
# 19666       7
# 19882       7
# 76408       6
# 19428       6
# 38896       6
# 110034      6
# 19144       6
# 76204       6
# 93628       6
# 19048       6
# 38564       6
# 76312       6
# 110108      6
# 18756       6
# 18826       6
# 57268       6
# 126099      6
# 126361      6
# 142905      6
# 93240       6
# 109896      6
# 126249      6
# 19878       5
# 19712       5
# 93760       5
# 19736       5
# 93850       5
# 8662        5
# 8462        5
# 19264       5
# 19490       5
# 18064       5
# 18878       5
# 19502       5
# 39276       5
# 19556       5
# 19796       5
# 39270       5
# 110092      5
# 17470       5
# 39308       5
# 93738       5
# 20062       4
# 19900       4
# 19908       4
# 19896       4
# 19988       4
# 19898       4
# 19954       4
# 19062       4
# 19472       4
# 19694       4
# 19962       4
# 19068       4
# 18470       4
# 19714       4
# 39350       4
# 19498       4
# 19744       4
# 20008       4
# 16265       4
# 39228       4
# 19862       3
# 19876       3
# 19928       3
# 39252       3
# 19874       3
# 19892       3
# 19984       3
# 39236       3
# 39424       3
# 76488       3
# 14662       3
# 19894       3
# 19934       3
# 19996       3
# 20048       3
# 76578       3
# 93700       3
# 18462       3
# 19662       3
# 19780       3
# 19470       2
# 19864       2
# 19672       2
# 19668       2
# 19682       2
# 19730       2
# 39280       2
# 39416       2
# 76550       2
# 7262        2
# 18262       2
# 19380       2
# 19776       2
# 19922       2
# 7662        2
# 12462       2
# 14663       2
# 19466       2
# 19486       2
# 19518       2
# 19704       1
# 19302       1
# 19432       1
# 19326       1
# 38892       1
# 18488       1
# 37838       1
# 57914       1
# 76472       1
# 18506       1
# 19628       1
# 76248       1
# 38368       1
# 38734       1
# 57692       1
# 17360       1
# 18942       1
# 36071       1
# 39018       1
# 57648       1
# 19746       0
# 19822       0
# 17334       0
# 17938       0
# 18316       0
# 37518       0
# 38722       0
# 57662       0
# 11279       0
# 14864       0
# 18120       0
# 57526       0
# 158141      0
# 18314       0
# 18714       0
# 37932       0
# 16506       0
# 14866       0
# 15996       0
# 17914       0

# %% [markdown]
# ### Small Batch Playlist

# %%
#psuedo-code 

#get user input
#extract song information using spotify API 
    #order information so that it fits KMeans model format
#feed formatted song data to KMeans model to classify song
#retrieve five most popular songs in the same category 
#return playlist of those five songs
    #each song has artist - albumn - song name
